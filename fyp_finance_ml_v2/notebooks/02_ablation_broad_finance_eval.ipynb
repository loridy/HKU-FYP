# %% [markdown]
# # 02 Full Ablation + Financial Evaluation
#
# Runs the broad-evaluation version and writes the four-panel summary figure.

# %%
# !python -m src.pipeline --mode synthetic --notebook 02
